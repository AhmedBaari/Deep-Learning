# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#import sklearn diabetes dataset 
from sklearn import datasets
df = pd.read_csv("Iris.csv")

# %%
print(df.head())
print(f"rows: {df.shape[0]}")
print(f"columns: {df.shape[1]}")
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# rows: 150
# columns: 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
correlation_matrix = df.loc[:, 'SepalLengthCm':'PetalWidthCm'].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
unique_values, counts = np.unique(df["Species"], return_counts=True)
unique_values[0] = unique_values[0] + "="+str(counts[0])
unique_values[1] = unique_values[1] + "="+str(counts[1])
unique_values[2] = unique_values[2] + "=" + str(counts[2])
plt.figure(figsize=(8, 6))
plt.axis('equal')
plt.pie(counts, labels=unique_values, startangle=140)
plt.title("Data Avilable for different Species")
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.histplot(data=df, x='SepalLengthCm', hue='Species',  multiple="stack", palette="viridis")
plt.title('Species Based on SepalLengthCm')

plt.subplot(1, 2, 2)
sns.histplot(data=df, x='SepalWidthCm', hue='Species', multiple="stack", palette="viridis")
plt.title('Species Based on SepalWidthCm')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.histplot(data=df, x='PetalLengthCm', hue='Species',  multiple="stack", palette="viridis")
plt.title('Species Based on PetalLengthCm')

plt.subplot(1, 2, 2)
sns.histplot(data=df, x='PetalWidthCm', hue='Species', multiple="stack", palette="viridis")
plt.title('Species Based on PetalWidthCm')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Preps
# 1. Import the data
# 2. View the data in different forms: head, info, describe, (correlation matrix)
# 3. Plots: Plot different columns in different ways
# 4. Data cleaning: Checking for outliers, checking for null values.
#
# ## Outcomes
# 1. Done
# 2. Done
# 3. Done
# 4. Yet to do outliers detection

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# All values are float, string is object, so well and good.

# %% [markdown]
# ## NEXT
# 1. Extract features, labels
# 2. Create train test split

# %% [markdown]
# ## Creating the model

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
